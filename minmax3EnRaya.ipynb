# %%
from search import *

class ThreeInARow(Problem):
    def __init__(self, initial = None, goal=None):
        super().__init__(initial, goal)
        self.board = [0, 0, 0,
                      0, 0, 0, 
                      0, 0, 0]

p = ThreeInARow()
print(p.board)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]
